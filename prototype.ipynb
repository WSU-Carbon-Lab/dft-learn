# %%
import dftlearn as dfl
from pathlib import Path

# %%
testing_dir = Path("/home/hduva/projects/dft-learn/tests/output")
output = dfl.load_data(testing_dir, width1=0.5, width2=12, max_energy=360)
# Out:
# /home/hduva/projects/dft-learn/.venv/lib/python3.12/site-packages/dftlearn/io/stobe.py:166: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat([o.df_energies for o in outputs], ignore_index=True),
